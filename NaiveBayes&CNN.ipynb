# %%
import pandas as pd

# %%
df = pd.read_csv('YTdata.csv')

# %%
df.head(10)
# Out:
#       Video ID                                              Title  \
# 0  9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1  Hpul0H1ddX8  REALITY - THAILAND &amp; BALI CINEMATIC TRAVEL...
# 2  kRTGOQEi75Q  Plastic Cans Manufacturing - Business Video(Te...
# 3  FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 4  tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 5  Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 6  RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 7  xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 8  HgS9q1Mfus0  Nobody Showed You the History Of India Like This!
# 9  mMz5d3qZKhI  हज़ारों कमाएं रोजाना | manufacturing business i...
#
#                                          Description       Category
# 0  Queen Elizabeth visits the science museum in l...     technology
# 1  Year 2018 was amazing, I had chance to travel ...         travel
# ...

# %%
df.shape
# Out:
# (11500, 4)

# %%
df.isnull().sum()
# Out:
# Video ID         0
# Title            0
# Description    194
# Category         0
# dtype: int64

# %%
df1 = df[df.isnull().any(axis=1)]
df1
# Out:
#           Video ID                                              Title  \
# 171    PTNc_dXjf5c  SCIENCE AND TECHNOLOGY STD 10 MCQ I TWIST MCQ ...
# 281    ywbcT2BFuDU  Top 10 Coolest Army Science and Technology Adv...
# 283    ULDHF7Mwy7c                           Jeans Manufacturing Unit
# 394    PTNc_dXjf5c  SCIENCE AND TECHNOLOGY STD 10 MCQ I TWIST MCQ ...
# 448    9e_8LCbV9L8                        Usborne Art and Music Books
# 453    9e_8LCbV9L8                        Usborne Art and Music Books
# 456    rrJbuF6zOIk                            babyfirst art and music
# 525    PTNc_dXjf5c  SCIENCE AND TECHNOLOGY STD 10 MCQ I TWIST MCQ ...
# 541    9e_8LCbV9L8                        Usborne Art and Music Books
# 576    PTNc_dXjf5c  SCIENCE AND TECHNOLOGY STD 10 MCQ I TWIST MCQ ...
# 624    rrJbuF6zOIk                            babyfirst art and music
# 642    5z46tbp6r38  Islandian | KazOut Art and Music Festival, Mau...
# ...

# %%
df = df.dropna()

# %%
df = df.reset_index(drop = True)
df
# Out:
#           Video ID                                              Title  \
# 0      9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1      Hpul0H1ddX8  REALITY - THAILAND &amp; BALI CINEMATIC TRAVEL...
# 2      kRTGOQEi75Q  Plastic Cans Manufacturing - Business Video(Te...
# 3      FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 4      tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 5      Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 6      RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 7      xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 8      HgS9q1Mfus0  Nobody Showed You the History Of India Like This!
# 9      mMz5d3qZKhI  हज़ारों कमाएं रोजाना | manufacturing business i...
# 10     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 11     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# ...

# %%
df.isnull().sum()
# Out:
# Video ID       0
# Title          0
# Description    0
# Category       0
# dtype: int64

# %%
import re
df['Description'] = df['Description'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
df['Description']
# Out:
# 0        Queen Elizabeth visits the science museum in l...
# 1        Year 2018 was amazing, I had chance to travel ...
# 2                 Gmail: enablemicroenterprises@gmail.com.
# 3        WASHINGTON — For the first time since he took ...
# 4        Barbie & Ken go on holiday vacation! Barbie tr...
# 5        The impulse to create art and music comes from...
# 6        Russell M. Nelson, M.D., Ph.D. was given the G...
# 7        Hello Guys, This is the last video from Arunac...
# 8                                   Be like SMART BANANA:
# 9        Manufacturing business ideas:- बगैर कुछ पैसे ल...
# 10       This is the evolution of art. I used music, fu...
# 11       Kiano shows us how she makes her favorite frie...
# 12       Thailand #BudgettriptoThailand FOR HOTEL BOOKI...
# 13       കാശ്മീരിലെ പ്രശ്നം എന്താണ് എന്നറിയാൻ ഈ വീഡിയോ ...
# 14       Full-time travel documentary! Also, you can vi...
# 15       H.s History 2019 question and answer paper/cla...
# ...

# %%
df['Description'] = df['Description'].apply(lambda x: re.split('http:\/\/.*', str(x))[0])
df['Description']
# Out:
# 0        Queen Elizabeth visits the science museum in l...
# 1        Year 2018 was amazing, I had chance to travel ...
# 2                 Gmail: enablemicroenterprises@gmail.com.
# 3        WASHINGTON — For the first time since he took ...
# 4        Barbie & Ken go on holiday vacation! Barbie tr...
# 5        The impulse to create art and music comes from...
# 6        Russell M. Nelson, M.D., Ph.D. was given the G...
# 7        Hello Guys, This is the last video from Arunac...
# 8                                   Be like SMART BANANA:
# 9        Manufacturing business ideas:- बगैर कुछ पैसे ल...
# 10       This is the evolution of art. I used music, fu...
# 11       Kiano shows us how she makes her favorite frie...
# 12       Thailand #BudgettriptoThailand FOR HOTEL BOOKING-
# 13       കാശ്മീരിലെ പ്രശ്നം എന്താണ് എന്നറിയാൻ ഈ വീഡിയോ ...
# 14       Full-time travel documentary! Also, you can vi...
# 15       H.s History 2019 question and answer paper/cla...
# ...

# %%
import sys

# %%
len(df.Description[15])
# Out:
# 90

# %%
sys.executable
# Out:
# '/home/abhishek/youtube_tutorial/JupyterYT/venv/bin/python3'

# %%
from langdetect import detect

# %%
detect('HS History Suggestion 2019 ')
# Out:
# 'en'

# %%
des_ctr = 0 
title_ctr = 0
ctr = 0

# %%
for j in range(df.shape[0]):
    if len(df.Description[j])<3:
        df.drop(j,inplace=True)
        ctr+=1
print(ctr)
# Out:
# 258

# %%
df = df.reset_index(drop=True)
df
# Out:
#           Video ID                                              Title  \
# 0      9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1      Hpul0H1ddX8  REALITY - THAILAND &amp; BALI CINEMATIC TRAVEL...
# 2      kRTGOQEi75Q  Plastic Cans Manufacturing - Business Video(Te...
# 3      FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 4      tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 5      Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 6      RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 7      xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 8      HgS9q1Mfus0  Nobody Showed You the History Of India Like This!
# 9      mMz5d3qZKhI  हज़ारों कमाएं रोजाना | manufacturing business i...
# 10     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 11     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# ...

# %%
for i in range(df.shape[0]):
    if(detect(df.Description[i])!='en'):
        df.drop(i,inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#          Video ID                                              Title  \
# 0     9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1     Hpul0H1ddX8  REALITY - THAILAND &amp; BALI CINEMATIC TRAVEL...
# 2     FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 3     tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 4     Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 5     RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 6     xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 7     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 8     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# 9     GyzKfo1q2EY  थाईलैंड घूमो मात्र 20000 रूपये में  | Travel B...
# 10    vE7BxinaBYA  H.s History 2019 question and answer paper/cla...
# 11    fFQRkRGE10w               Day for Night: Merging Art and Music
# 12    C3hcRn8EavQ     TRYING FAST FOOD IN BARBADOS: KIA DRIVE-THRU!!
# ...

# %%
for i in range(df.shape[0]):
    if(detect(df.Title[i])!='en'):
        df.drop(i,inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#          Video ID                                              Title  \
# 0     9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1     FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 2     tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 3     Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 4     RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 5     xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 6     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 7     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# 8     vE7BxinaBYA  H.s History 2019 question and answer paper/cla...
# 9     fFQRkRGE10w               Day for Night: Merging Art and Music
# 10    sUO0Xjnc6Vg  Drones, art and music | Luis Rodrigues | TEDxC...
# 11    13E5azGDK1k  FINE ART Music and Painting PEACEFUL SELECTION...
# 12    ZDcaDv0U8yw           The computer as artist: AI art and music
# ...

# %%
for i in range(df.shape[0]):
    if(detect(df.Title[i])!='en' or detect(df.Description[i])!='en' ):
        df.drop(i,inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#          Video ID                                              Title  \
# 0     9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1     FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 2     tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 3     Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 4     RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 5     xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 6     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 7     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# 8     vE7BxinaBYA  H.s History 2019 question and answer paper/cla...
# 9     fFQRkRGE10w               Day for Night: Merging Art and Music
# 10    sUO0Xjnc6Vg  Drones, art and music | Luis Rodrigues | TEDxC...
# 11    13E5azGDK1k  FINE ART Music and Painting PEACEFUL SELECTION...
# 12    ZDcaDv0U8yw           The computer as artist: AI art and music
# ...

# %%
df.drop(29)
# Out:
#          Video ID                                              Title  \
# 0     9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1     FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 2     tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 3     Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 4     RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 5     xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 6     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 7     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# 8     vE7BxinaBYA  H.s History 2019 question and answer paper/cla...
# 9     fFQRkRGE10w               Day for Night: Merging Art and Music
# 10    sUO0Xjnc6Vg  Drones, art and music | Luis Rodrigues | TEDxC...
# 11    13E5azGDK1k  FINE ART Music and Painting PEACEFUL SELECTION...
# 12    ZDcaDv0U8yw           The computer as artist: AI art and music
# ...

# %%
df.reset_index(drop=True)
df
# Out:
#          Video ID                                              Title  \
# 0     9PqWX_ggir0  Queen Elizabeth Visits The Science Museum In L...
# 1     FrQ5Z-43IyI  Trump&#39;s New Science Adviser Says It&#39;s ...
# 2     tY88O5OS1uw  Barbie &amp; Ken Airplane Travel Routine - Hol...
# 3     Xcmijqbd8kc  &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 4     RSuhKCzFXEg  Governor&#39;s Medal for Science and Technolog...
# 5     xS0Iuym2ejs    HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 6     3_mx6rYXuOg  Evolution of Art (1800 AD - 2017) - Music, Pai...
# 7     qJZpZex25qM                 Fried Street Food In Kenya • Tasty
# 8     vE7BxinaBYA  H.s History 2019 question and answer paper/cla...
# 9     fFQRkRGE10w               Day for Night: Merging Art and Music
# 10    sUO0Xjnc6Vg  Drones, art and music | Luis Rodrigues | TEDxC...
# 11    13E5azGDK1k  FINE ART Music and Painting PEACEFUL SELECTION...
# 12    ZDcaDv0U8yw           The computer as artist: AI art and music
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
vectorizer = CountVectorizer(
    stop_words="english"
)

# %%
x_df = df[["Title","Description"]]
x_df
# Out:
#                                                   Title  \
# 0     Queen Elizabeth Visits The Science Museum In L...
# 1     Trump&#39;s New Science Adviser Says It&#39;s ...
# 2     Barbie &amp; Ken Airplane Travel Routine - Hol...
# 3     &#39;Hey Bill Nye, What&#39;s the Evolutionary...
# 4     Governor&#39;s Medal for Science and Technolog...
# 5       HOW TO TRAVEL IN UNEXPLORED ARUNACHAL PRADESH ?
# 6     Evolution of Art (1800 AD - 2017) - Music, Pai...
# 7                    Fried Street Food In Kenya • Tasty
# 8     H.s History 2019 question and answer paper/cla...
# 9                  Day for Night: Merging Art and Music
# 10    Drones, art and music | Luis Rodrigues | TEDxC...
# 11    FINE ART Music and Painting PEACEFUL SELECTION...
# 12             The computer as artist: AI art and music
# 13    Amazing Automatic Melting Aluminum Manufacturi...
# 14    CARTA: Evolutionary Origins of Art and Aesthet...
# 15    Street Food in Italy - FRESH SEAFOOD &amp; FIS...
# ...

# %%
y_df = df[["Category"]]
y_df.shape[1]
# Out:
# 1

# %%
xTrain,xTest,yTrain,yTest = train_test_split(x_df,y_df,test_size=0.25,random_state=0)

# %%
type(yTest)
# Out:
# pandas.core.frame.DataFrame

# %%
training_features=vectorizer.fit_transform(xTrain["Title"],xTrain["Description"])

# %%
training_features
# Out:
# <6264x1255 sparse matrix of type '<class 'numpy.int64'>'
# 	with 43933 stored elements in Compressed Sparse Row format>

# %%
training_features.shape
# Out:
# (6264, 1255)

# %%
test_features = vectorizer.transform(xTest['Title'])

# %%
training_features
# Out:
# <6264x1255 sparse matrix of type '<class 'numpy.int64'>'
# 	with 43933 stored elements in Compressed Sparse Row format>

# %%
training_features.shape
# Out:
# (6264, 1255)

# %%
yTrain.shape
# Out:
# (6264, 1)

# %%
yTest.shape
# Out:
# (2089, 1)

# %%
test_features
# Out:
# <2089x1255 sparse matrix of type '<class 'numpy.int64'>'
# 	with 14394 stored elements in Compressed Sparse Row format>

# %%
test_features.shape
# Out:
# (2089, 1255)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(training_features.toarray(), yTrain)
# Out:
# /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb.predict(training_features.toarray())
y_pred
# Out:
# array(['food', 'art', 'history', ..., 'history', 'travel', 'food'],
#       dtype='<U13')

# %%
from sklearn.metrics import accuracy_score

# %%
print("Training Accuracy:",accuracy_score(yTrain, y_pred))
# Out:
# Training Accuracy: 0.9998403575989783

# %%
y_pred.shape
# Out:
# (6264,)

# %%
y_pred_test = gnb.predict(test_features.toarray())

# %%
print("Test Accuracy:",accuracy_score(yTest, y_pred_test))
# Out:
# Test Accuracy: 0.9995213020584012

# %%
type(y_pred_test)
# Out:
# numpy.ndarray

# %%
from sklearn.preprocessing import label_binarize

# %%
Y_test = label_binarize(yTest,classes=[0,1,2,3,4,5])

# %%
df_new = pd.DataFrame(data=y_pred_test.flatten())

# %%
Y_pred_test = label_binarize(df_new,classes=[0,1,2,3,4,5])

# %%
Y_test = Y_test.reshape((-1))
Y_pred_test = Y_pred_test.reshape((-1))

# %%
Y_pred_test.shape
# Out:
# (12534,)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt

# %%
precision = dict()
recall = dict()
average_precision = dict()
for i in range(6):
    precision[i], recall[i], _ = precision_recall_curve(Y_test[:,i],Y_pred_test[:,i])
    average_precision[i] = average_precision_score(Y_test[:,i], Y_pred_test[:,i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(Y_test.ravel(),Y_pred_test.ravel())
average_precision["micro"] = average_precision_score(Y_test, Y_pred_test,average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'.format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: nan
# /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/sklearn/metrics/ranking.py:526: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/sklearn/metrics/ranking.py:526: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]

# %%
plt.figure()
plt.step(recall['micro'], precision['micro'], color='b', alpha=0.2,where='post')
plt.fill_between(recall["micro"], precision["micro"], alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Average precision score, micro-averaged over all classes: AP={0:0.2f}'.format(average_precision["micro"]))
# Out:
# Text(0.5, 1.0, 'Average precision score, micro-averaged over all classes: AP=nan')

# %%
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Dense, Input, GlobalMaxPooling1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from keras.initializers import Constant
# Out:
# Using TensorFlow backend.

# %%
MAX_SEQUENCE_LENGTH = 1000
MAX_NUM_WORDS = 20000
EMBEDDING_DIM = 100
TEST_SIZE = 0.2

# %%
embeddings_index = {}
with open('glove.6B.100d.txt') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Category']=le.fit_transform(df["Category"])

# %%
texts=[]
df.shape[0]
labels=[]

# %%
for i in range(df.shape[0]):
    texts.append(df['Title'][i] and df['Description'][i])
    labels.append(df['Category'][i])

# %%
len(texts)
# Out:
# 8353

# %%
len(labels)
# Out:
# 8353

# %%
labels
# Out:
# [4,
#  4,
#  5,
#  0,
#  4,
#  5,
#  0,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  3,
#  0,
#  1,
#  3,
#  0,
#  2,
#  5,
#  3,
#  4,
#  2,
#  4,
#  1,
#  1,
#  4,
#  5,
#  2,
#  3,
#  5,
#  1,
#  1,
#  0,
#  1,
#  4,
#  2,
#  1,
#  2,
#  4,
#  1,
#  5,
#  2,
#  1,
#  0,
#  3,
#  1,
#  2,
#  3,
#  0,
#  3,
#  1,
#  4,
#  0,
#  1,
#  5,
#  5,
#  5,
#  4,
#  2,
#  5,
#  2,
#  3,
#  5,
#  4,
#  1,
#  2,
#  0,
#  2,
#  3,
#  4,
#  5,
#  1,
#  0,
#  4,
#  1,
#  0,
#  5,
#  2,
#  1,
#  3,
#  0,
#  0,
#  1,
#  1,
#  2,
#  1,
#  3,
#  5,
#  5,
#  2,
#  5,
#  0,
#  2,
#  5,
#  4,
#  1,
#  1,
#  3,
#  1,
#  4,
#  5,
#  0,
#  0,
#  3,
#  0,
#  3,
#  1,
#  0,
#  5,
#  1,
#  0,
#  1,
#  1,
#  5,
#  3,
#  2,
#  5,
#  4,
#  2,
#  3,
#  4,
#  1,
#  0,
#  4,
#  0,
#  2,
#  3,
#  0,
#  5,
#  2,
#  0,
#  2,
#  2,
#  4,
#  2,
#  0,
#  0,
#  3,
#  4,
#  2,
#  5,
#  2,
#  1,
#  4,
#  2,
#  5,
#  5,
#  3,
#  0,
#  0,
#  3,
#  4,
#  3,
#  2,
#  3,
#  3,
#  5,
#  1,
#  4,
#  4,
#  0,
#  0,
#  0,
#  4,
#  5,
# ...

# %%
tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 2550 unique tokens.

# %%
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

# %%
labels = to_categorical(np.asarray(labels))

# %%
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', labels.shape)
# Out:
# Shape of data tensor: (8353, 1000)
# Shape of label tensor: (8353, 6)

# %%
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
num_validation_samples = int(TEST_SIZE * data.shape[0])
x_conv_train = data[:-num_validation_samples]
y_conv_train = labels[:-num_validation_samples]
x_conv_test = data[-num_validation_samples:]
y_conv_test = labels[-num_validation_samples:]

# %%
num_words = min(MAX_NUM_WORDS, len(word_index)) + 1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i > MAX_NUM_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(num_words,EMBEDDING_DIM,embeddings_initializer=Constant(embedding_matrix),input_length=MAX_SEQUENCE_LENGTH,trainable=False)

# %%
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = MaxPooling1D(5)(x)
x = Conv1D(128, 5, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(len(labels_index), activation='softmax')(x)

model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['acc'])
# Out:
# WARNING:tensorflow:From /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.fit(x_conv_train, y_conv_train,
          batch_size=128,
          epochs=10,
          validation_data=(x_conv_test, y_conv_test))
# Out:
# WARNING:tensorflow:From /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/abhishek/youtube_tutorial/JupyterYT/venv/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 6683 samples, validate on 1670 samples
# Epoch 1/10
# 6683/6683 [==============================] - 56s 8ms/step - loss: 0.8398 - acc: 0.7124 - val_loss: 0.3922 - val_acc: 0.8533
# Epoch 2/10
# 6683/6683 [==============================] - 51s 8ms/step - loss: 0.1572 - acc: 0.9672 - val_loss: 0.2690 - val_acc: 0.9246
# Epoch 3/10
# ...
